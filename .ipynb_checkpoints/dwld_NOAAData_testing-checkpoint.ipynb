# %%
import pandas as pd
import windpy as wp

# %%
lat = 51.525
lon = -0.129
stations = wp.NOAA.findStation(centre = [lat, lon], radius = 10, unit = 'km')
print(stations)
# Out:
# Loading info local backup from C:\ProgramData\Anaconda3\lib\site-packages\windpy-0.3.0-py3.9.egg\windpy\NOAA\tempdata\isd-history.txt
#                USAF   WBAN       STATION NAME  CT   ST  CALL     LAT    LON  \
# 03770099999  037700  99999      ST JAMES PARK  UK  NaN   NaN  51.500 -0.117
# 03778099999  037780  99999  LONDON WEA CENTER  UK  NaN   NaN  51.517 -0.117
# 03779099999  037790  99999  LONDON WEA CENTER  UK  NaN  EGRB  51.500 -0.117
# 03783099999  037830  99999     GALLIONS REACH  UK  NaN   NaN  51.500 -0.067
#
#              ELEV(M)      BEGIN        END
# 03770099999      5.0 2009-12-18 2022-11-16
# 03778099999     23.0 1973-01-01 2003-05-14
# 03779099999     39.0 1992-04-01 1997-12-31
# 03783099999     12.0 1973-01-01 1979-10-11

# %%
raw_data = wp.NOAA.getNOAA(ID = 3779099999, yearStart = 2000, yearEnd = 2006)
# Out:
# Loading local backup from C:\ProgramData\Anaconda3\lib\site-packages\windpy-0.3.0-py3.9.egg\windpy\NOAA\tempdata\03779099999_2000_2006.pkl

# %%
raw_data.describe()
# Out:
#             WindDir     WindSpeed  SeaLevelPressure   Temperature  \
# count  59855.000000  59855.000000      59855.000000  59855.000000
# mean     237.302531     51.025413       1030.219567     13.022591
# std      194.442430    211.312803        368.925445     25.874968
# min       10.000000      0.000000        964.900000     -2.000000
# 25%      110.000000      2.600000       1008.900000      8.100000
# 50%      230.000000      4.100000       1015.900000     12.100000
# 75%      290.000000      5.100000       1021.900000     16.400000
# max      999.000000    999.900000       9999.900000    999.900000
#
#        DewPointTemp      CloudHgt     Visibility  OC1_0  MW1_0  AJ1_0  RH1_2
# count  59855.000000  59855.000000   59855.000000    0.0    0.0    0.0    0.0
# mean       7.568758  28420.942377  208169.004929    NaN    NaN    NaN    NaN
# std       29.707717  38860.318446  384846.068151    NaN    NaN    NaN    NaN
# min      -13.900000     15.000000       0.000000    NaN    NaN    NaN    NaN
# 25%        3.100000    900.000000   14000.000000    NaN    NaN    NaN    NaN
# 50%        7.000000   7500.000000   25000.000000    NaN    NaN    NaN    NaN
# 75%       10.500000  22000.000000   40000.000000    NaN    NaN    NaN    NaN
# max      999.900000  99999.000000  999999.000000    NaN    NaN    NaN    NaN

# %%
#check noaa data for temp errors
df = raw_data[raw_data.Temperature != 999.9]
df.describe()
# Out:
#             WindDir     WindSpeed  SeaLevelPressure   Temperature  \
# count  59816.000000  59816.000000      59816.000000  59816.000000
# mean     236.966698     50.606095       1024.371340     12.379148
# std      193.825996    210.416759        289.314572      5.875880
# min       10.000000      0.000000        964.900000     -2.000000
# 25%      110.000000      2.600000       1008.900000      8.100000
# 50%      230.000000      4.100000       1015.900000     12.100000
# 75%      290.000000      5.100000       1021.900000     16.400000
# max      999.000000    999.900000       9999.900000     37.400000
#
#        DewPointTemp      CloudHgt     Visibility  OC1_0  MW1_0  AJ1_0  RH1_2
# count  59816.000000  59816.000000   59816.000000    0.0    0.0    0.0    0.0
# mean       6.921758  28385.661311  207882.894125    NaN    NaN    NaN    NaN
# std       15.513117  38838.330233  384619.691587    NaN    NaN    NaN    NaN
# min      -13.900000     15.000000       0.000000    NaN    NaN    NaN    NaN
# 25%        3.100000    900.000000   14000.000000    NaN    NaN    NaN    NaN
# 50%        7.000000   7500.000000   25000.000000    NaN    NaN    NaN    NaN
# 75%       10.500000  22000.000000   40000.000000    NaN    NaN    NaN    NaN
# max      999.900000  99999.000000  999999.000000    NaN    NaN    NaN    NaN

# %%
## Read in an EPW file to a Pandas dataframe
def readNOAA_DesignDay(df):
    htg_996= df['Temperature'].quantile(q=0.004)
    htg_990= df['Temperature'].quantile(q=0.010)
    clg_004= df['Temperature'].quantile(q=0.996)
    clg_010= df['Temperature'].quantile(q=0.99)
    return htg_996,htg_990,clg_004,clg_010

# %%
htg_996,htg_990,clg_004,clg_010 = readNOAA_DesignDay(df)
htg_996,htg_990,clg_004,clg_010
# Out:
# (-0.1, 0.7, 29.1, 27.1)

# %%
stations = wp.NOAA.findStation(name = 'london')
stations
# Out:
# Loading info local backup from C:\ProgramData\Anaconda3\lib\site-packages\windpy-0.3.0-py3.9.egg\windpy\NOAA\tempdata\isd-history.txt
#                USAF   WBAN                  STATION NAME  CT   ST  CALL  \
# 03775099999  037750  99999                 KEW-IN-LONDON  UK  NaN   NaN
# 03778099999  037780  99999             LONDON WEA CENTER  UK  NaN   NaN
# 03779099999  037790  99999             LONDON WEA CENTER  UK  NaN  EGRB
# 03908499999  039084  99999          LONDONDERRY EGLINTON  UK  NaN  EGAE
# 24799099999  247990  99999             JEK-LONDON (LAKE)  RS  NaN   NaN
# 68858099999  688580  99999                   EAST LONDON  SF  NaN  FAEL
# 71622099999  716220  99999                LONDON CS  ONT  CA  NaN  CWSN
# 71623099999  716230  99999                        LONDON  CA  NaN  CYXU
# 72329103849  723291  03849              LONDON-CORBIN AP  US   KY  KLOZ
# 72329303849  723293  03849              LONDON-CORBIN AP  US   KY  KLOZ
# 72504614707  725046  14707     GROTON-NEW LONDON AIRPORT  US   CT  KGON
# 72504699999  725046  99999             GROTON NEW LONDON  US   CT  KGON
# 72504799999  725047  99999  NEW LONDON LEDGE COAST GUARD  US   CT   NaN
# 72623099999  726230  99999                LONDON AIRPORT  CA  NaN   NaN
# 99475099999  994750  99999  NEW LONDON LEDGE - LEDGE LIG  US   CT   NaN
# 99728399999  997283  99999                    NEW LONDON  US   CT   NaN
# 99999903849  999999  03849              LONDON-CORBIN AP  US   KY  KLOZ
#
#                 LAT      LON  ELEV(M)      BEGIN        END
# 03775099999  51.467   -0.317      5.0 1929-10-01 1982-05-10
# 03778099999  51.517   -0.117     23.0 1973-01-01 2003-05-14
# 03779099999  51.500   -0.117     39.0 1992-04-01 1997-12-31
# 03908499999  55.043   -7.161      6.7 1990-04-24 2022-11-16
# 24799099999  62.117  149.517    808.0 1969-01-01 1983-12-30
# 68858099999 -33.036   27.826    132.6 1949-01-01 2022-11-16
# 71622099999  43.033  -81.150    278.0 2004-08-03 2022-11-03
# 71623099999  43.036  -81.154    278.0 1955-07-02 2022-11-16
# 72329103849  37.087  -84.077    369.1 1985-05-31 1990-02-06
# 72329303849  37.087  -84.077    369.1 1990-02-08 1991-02-20
# 72504614707  41.328  -72.049      2.5 1943-01-18 2022-11-17
# 72504699999  41.317  -72.033      3.0 2000-01-01 2003-12-31
# 72504799999  41.300  -72.080      8.0 1975-09-11 1987-04-27
# 72623099999  43.033  -81.150    278.0 1973-01-01 1977-06-30
# 99475099999  41.310  -72.080     20.0 2004-06-08 2022-11-16
# 99728399999  41.350  -72.080      8.5 2008-01-01 2022-11-16
# 99999903849  37.087  -84.077    369.1 1954-10-11 1965-01-01

# %%
stations = wp.NOAA.findStation(name = 'houston')
stations
# Out:
# Loading info local backup from C:\ProgramData\Anaconda3\lib\site-packages\windpy-0.3.0-py3.9.egg\windpy\NOAA\tempdata\isd-history.txt
#                USAF   WBAN                 STATION NAME  CT  ST  CALL     LAT  \
# 72059400188  720594  00188        HOUSTON DUNN HELISTOP  US  TX  KMCJ  29.717
# 72059499999  720594  99999        HOUSTON/DUNN HELISTOP  US  TX  KMCJ  29.717
# 72061700208  720617  00208    HOUSTON EXECUTIVE AIRPORT  US  TX  KTME  29.800
# 72063700223  720637  00223    HOUSTON SOUTHWEST AIRPORT  US  TX  KAXH  29.500
# 72242999999  722429  99999           HOUSTON/D.W. HOOKS  US  TX  KDWH  30.067
# 72243399999  722433  99999                 WEST HOUSTON  US  TX  KIWS  29.818
# 72243699999  722436  99999            HOUSTON/ELLINGTON  US  TX  KEFD  29.600
# 72446203073  724462  03073   CROCKETT HOUSTON COUNTY AP  US  TX  KDKR  31.307
# 72446299999  724462  99999                   HOUSTON CO  US  TX  KDKR  31.307
# 99999912918  999999  12918   HOUSTON WILLIAM P HOBBY AP  US  TX  KHOU  29.638
# 99999912960  999999  12960  HOUSTON INTERCONTINENTAL AP  US  TX  KIAH  29.980
#
#                 LON  ELEV(M)      BEGIN        END
# 72059400188 -95.383     69.2 2009-01-01 2022-11-17
# 72059499999 -95.383     69.0 2008-10-22 2008-12-31
# 72061700208 -95.900     51.2 2009-02-04 2022-11-17
# 72063700223 -95.477     21.0 2009-06-01 2022-11-17
# 72242999999 -95.550     46.0 1986-09-16 1997-12-31
# 72243399999 -95.673     33.8 1985-01-30 1985-11-29
# 72243699999 -95.167     10.0 2000-01-01 2004-12-31
# 72446203073 -95.404    106.1 2005-06-11 2022-11-17
# 72446299999 -95.404    106.1 2008-01-03 2008-12-30
# 99999912918 -95.282     14.3 1948-07-01 1969-06-01
# 99999912960 -95.360     32.0 1969-06-01 1972-12-31

# %%
ID_hou = 72061700208

# %%
raw_data = wp.NOAA.getNOAA(ID = ID_hou, yearStart = 2011, yearEnd = 2021)
raw_data.describe()
# Out:
# Loading local backup from C:\ProgramData\Anaconda3\lib\site-packages\windpy-0.3.0-py3.9.egg\windpy\NOAA\tempdata\72061700208_2011_2021.pkl
#              WindDir      WindSpeed  SeaLevelPressure    Temperature  \
# count  284099.000000  284099.000000      2.840990e+05  284099.000000
# mean      342.890031      24.450582      9.999900e+03      38.631517
# std       346.836410     143.578189      5.296179e-08     131.362192
# min        10.000000       0.000000      9.999900e+03     -40.000000
# 25%       130.000000       2.100000      9.999900e+03      16.000000
# 50%       180.000000       3.100000      9.999900e+03      23.000000
# 75%       350.000000       5.100000      9.999900e+03      27.000000
# max       999.000000     999.900000      9.999900e+03     999.900000
#
#         DewPointTemp       CloudHgt     Visibility  OC1_0  MW1_0  AJ1_0  RH1_2
# count  284099.000000  284099.000000  284099.000000    0.0    0.0    0.0    0.0
# mean       47.339697   20718.098765   43131.905132    NaN    NaN    NaN    NaN
# std       172.213422   25344.959312  168874.528047    NaN    NaN    NaN    NaN
# min       -15.000000       0.000000       0.000000    NaN    NaN    NaN    NaN
# 25%        11.000000    1280.000000   11265.000000    NaN    NaN    NaN    NaN
# 50%        19.000000   22000.000000   16093.000000    NaN    NaN    NaN    NaN
# 75%        23.000000   22000.000000   16093.000000    NaN    NaN    NaN    NaN
# max       999.900000   99999.000000  999999.000000    NaN    NaN    NaN    NaN

# %%
#check noaa data for temp errors
df = raw_data[raw_data.Temperature != 999.9]
df.describe()
# Out:
#              WindDir      WindSpeed  SeaLevelPressure    Temperature  \
# count  278912.000000  278912.000000      2.789120e+05  278912.000000
# mean      331.122354       6.985092      9.999900e+03      20.754553
# std       338.511714      60.349895      5.217417e-08       8.528278
# min        10.000000       0.000000      9.999900e+03     -40.000000
# 25%       130.000000       2.100000      9.999900e+03      15.000000
# 50%       180.000000       3.100000      9.999900e+03      22.000000
# 75%       340.000000       4.600000      9.999900e+03      27.000000
# max       999.000000     999.900000      9.999900e+03      40.000000
#
#         DewPointTemp       CloudHgt     Visibility  OC1_0  MW1_0  AJ1_0  RH1_2
# count  278912.000000  278912.000000  278912.000000    0.0    0.0    0.0    0.0
# mean       29.635190   19270.347346   26260.035395    NaN    NaN    NaN    NaN
# std       114.151805   23177.888323  112217.007226    NaN    NaN    NaN    NaN
# min       -15.000000       0.000000       0.000000    NaN    NaN    NaN    NaN
# 25%        11.000000    1250.000000   11265.000000    NaN    NaN    NaN    NaN
# 50%        19.000000   22000.000000   16093.000000    NaN    NaN    NaN    NaN
# 75%        23.000000   22000.000000   16093.000000    NaN    NaN    NaN    NaN
# max       999.900000   99999.000000  999999.000000    NaN    NaN    NaN    NaN

# %%
df['Temperature'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
htg_996,htg_990,clg_004,clg_010 = readNOAA_DesignDay(df)
htg_996,htg_990,clg_004,clg_010
# Out:
# (-3.0, 0.0, 37.0, 36.0)

# %%
lat = 29.794857
lon = -95.81653
stations = wp.NOAA.findStation(centre = [lat, lon], radius = 10, unit = 'km')
stations
# Out:
# Loading info local backup from C:\ProgramData\Anaconda3\lib\site-packages\windpy-0.3.0-py3.9.egg\windpy\NOAA\tempdata\isd-history.txt
#                USAF   WBAN               STATION NAME  CT  ST  CALL   LAT  \
# 72061700208  720617  00208  HOUSTON EXECUTIVE AIRPORT  US  TX  KTME  29.8
#
#               LON  ELEV(M)      BEGIN        END
# 72061700208 -95.9     51.2 2009-02-04 2022-11-17

# %%
stations['USAF'][0]+stations['WBAN'][0]
# Out:
# '72061700208'

# %%
#get dataframe for temperature data based on lat, long coords
lat = 29.794857
lon = -95.81653
stations = wp.NOAA.findStation(centre = [lat, lon], radius = 10, unit = 'km')
stations
# Out:
# Loading info local backup from C:\ProgramData\Anaconda3\lib\site-packages\windpy-0.3.0-py3.9.egg\windpy\NOAA\tempdata\isd-history.txt
#                USAF   WBAN               STATION NAME  CT  ST  CALL   LAT  \
# 72061700208  720617  00208  HOUSTON EXECUTIVE AIRPORT  US  TX  KTME  29.8
#
#               LON  ELEV(M)      BEGIN        END
# 72061700208 -95.9     51.2 2009-02-04 2022-11-17

# %%
stations.shape[0]
# Out:
# 1

# %%
if stations.shape[0] > 0:
    id_loc = stations.index.astype('str')[0]
    print(id_loc)
else:
    id_loc = None
# Out:
# 72061700208

# %%
id_loc
# Out:
# '72061700208'

# %%
raw_data = wp.NOAA.getNOAA(ID = id_loc, yearStart = 2011, yearEnd = 2021)
raw_data.describe()
# Out:
# Loading local backup from C:\ProgramData\Anaconda3\lib\site-packages\windpy-0.3.0-py3.9.egg\windpy\NOAA\tempdata\72061700208_2011_2021.pkl
#              WindDir      WindSpeed  SeaLevelPressure    Temperature  \
# count  284099.000000  284099.000000      2.840990e+05  284099.000000
# mean      342.890031      24.450582      9.999900e+03      38.631517
# std       346.836410     143.578189      5.296179e-08     131.362192
# min        10.000000       0.000000      9.999900e+03     -40.000000
# 25%       130.000000       2.100000      9.999900e+03      16.000000
# 50%       180.000000       3.100000      9.999900e+03      23.000000
# 75%       350.000000       5.100000      9.999900e+03      27.000000
# max       999.000000     999.900000      9.999900e+03     999.900000
#
#         DewPointTemp       CloudHgt     Visibility  OC1_0  MW1_0  AJ1_0  RH1_2
# count  284099.000000  284099.000000  284099.000000    0.0    0.0    0.0    0.0
# mean       47.339697   20718.098765   43131.905132    NaN    NaN    NaN    NaN
# std       172.213422   25344.959312  168874.528047    NaN    NaN    NaN    NaN
# min       -15.000000       0.000000       0.000000    NaN    NaN    NaN    NaN
# 25%        11.000000    1280.000000   11265.000000    NaN    NaN    NaN    NaN
# 50%        19.000000   22000.000000   16093.000000    NaN    NaN    NaN    NaN
# 75%        23.000000   22000.000000   16093.000000    NaN    NaN    NaN    NaN
# max       999.900000   99999.000000  999999.000000    NaN    NaN    NaN    NaN

# %%
#check noaa data for temp errors
df = raw_data[raw_data.Temperature != 999.9]
df.describe()
# Out:
#              WindDir      WindSpeed  SeaLevelPressure    Temperature  \
# count  278912.000000  278912.000000      2.789120e+05  278912.000000
# mean      331.122354       6.985092      9.999900e+03      20.754553
# std       338.511714      60.349895      5.217417e-08       8.528278
# min        10.000000       0.000000      9.999900e+03     -40.000000
# 25%       130.000000       2.100000      9.999900e+03      15.000000
# 50%       180.000000       3.100000      9.999900e+03      22.000000
# 75%       340.000000       4.600000      9.999900e+03      27.000000
# max       999.000000     999.900000      9.999900e+03      40.000000
#
#         DewPointTemp       CloudHgt     Visibility  OC1_0  MW1_0  AJ1_0  RH1_2
# count  278912.000000  278912.000000  278912.000000    0.0    0.0    0.0    0.0
# mean       29.635190   19270.347346   26260.035395    NaN    NaN    NaN    NaN
# std       114.151805   23177.888323  112217.007226    NaN    NaN    NaN    NaN
# min       -15.000000       0.000000       0.000000    NaN    NaN    NaN    NaN
# 25%        11.000000    1250.000000   11265.000000    NaN    NaN    NaN    NaN
# 50%        19.000000   22000.000000   16093.000000    NaN    NaN    NaN    NaN
# 75%        23.000000   22000.000000   16093.000000    NaN    NaN    NaN    NaN
# max       999.900000   99999.000000  999999.000000    NaN    NaN    NaN    NaN

# %%
## Read in an EPW file to a Pandas dataframe
def readNOAA_DesignDay(df):
    htg_996= df['Temperature'].quantile(q=0.004)
    htg_990= df['Temperature'].quantile(q=0.010)
    clg_004= df['Temperature'].quantile(q=0.996)
    clg_010= df['Temperature'].quantile(q=0.99)
    return htg_996,htg_990,clg_004,clg_010

# %%
df['Temperature'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
htg_996,htg_990,clg_004,clg_010 = readNOAA_DesignDay(df)
htg_996,htg_990,clg_004,clg_010
# Out:
# (-3.0, 0.0, 37.0, 36.0)

# %%
def getDDFromNOAA(lat,lon,rad=10,years=10):
    stations = wp.NOAA.findStation(centre = [lat, lon], radius = rad, unit = 'km')
    if stations.shape[0] > 0:
        id_loc = stations.index.astype('str')[0]
    else:
        id_loc = None
    if id_loc is not None:
        raw_data = wp.NOAA.getNOAA(ID = id_loc, yearStart = 2011, yearEnd = 2021)
        df = raw_data[raw_data.Temperature != 999.9]
    else:
        df = None
    return df

# %%
st = getDDFromNOAA(29.794857,-95.81653)
st.describe()
#lat = 29.794857
#lon = -95.81653
# Out:
# Loading info local backup from C:\ProgramData\Anaconda3\lib\site-packages\windpy-0.3.0-py3.9.egg\windpy\NOAA\tempdata\isd-history.txt
# Loading local backup from C:\ProgramData\Anaconda3\lib\site-packages\windpy-0.3.0-py3.9.egg\windpy\NOAA\tempdata\72061700208_2011_2021.pkl
#              WindDir      WindSpeed  SeaLevelPressure    Temperature  \
# count  278912.000000  278912.000000      2.789120e+05  278912.000000
# mean      331.122354       6.985092      9.999900e+03      20.754553
# std       338.511714      60.349895      5.217417e-08       8.528278
# min        10.000000       0.000000      9.999900e+03     -40.000000
# 25%       130.000000       2.100000      9.999900e+03      15.000000
# 50%       180.000000       3.100000      9.999900e+03      22.000000
# 75%       340.000000       4.600000      9.999900e+03      27.000000
# max       999.000000     999.900000      9.999900e+03      40.000000
#
#         DewPointTemp       CloudHgt     Visibility  OC1_0  MW1_0  AJ1_0  RH1_2
# count  278912.000000  278912.000000  278912.000000    0.0    0.0    0.0    0.0
# mean       29.635190   19270.347346   26260.035395    NaN    NaN    NaN    NaN
# std       114.151805   23177.888323  112217.007226    NaN    NaN    NaN    NaN
# min       -15.000000       0.000000       0.000000    NaN    NaN    NaN    NaN
# 25%        11.000000    1250.000000   11265.000000    NaN    NaN    NaN    NaN
# 50%        19.000000   22000.000000   16093.000000    NaN    NaN    NaN    NaN
# 75%        23.000000   22000.000000   16093.000000    NaN    NaN    NaN    NaN
# max       999.900000   99999.000000  999999.000000    NaN    NaN    NaN    NaN

# %%
st['Temperature'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
htg_996,htg_990,clg_004,clg_010 = readNOAA_DesignDay(st)
htg_996,htg_990,clg_004,clg_010
# Out:
# (-3.0, 0.0, 37.0, 36.0)
